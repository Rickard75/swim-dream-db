# %% [markdown]
# # Sandbox Zone
# #### This space goal is to master Python tools and snippets to use in executive code all around the projects: my graveyard code.

# %%
# Python Tool : read specific section of a file

read_file("./DOCS/test.txt", 1, 5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Python Tool : read specific section of a file
#       2
# ----> 3 read_file("./DOCS/test.txt", 1, 5)
#
# NameError: name 'read_file' is not defined
